# %%
import pandas as pd

# %%
cars=pd.read_csv(r'C:\Users\KIIT\Downloads\ClassNotebooks\cars.csv')

# %%
cars.shape
# Out:
# (53, 17)

# %%
cars.head(10)
# Out:
#    YEAR        Make                            Model        Size  (kW)  \
# 0  2012  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 1  2012      NISSAN                             LEAF    MID-SIZE    80
# 2  2013        FORD                   FOCUS ELECTRIC     COMPACT   107
# 3  2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 4  2013      NISSAN                             LEAF    MID-SIZE    80
# 5  2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
# 6  2013       SMART      FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35
# 7  2013       TESLA         MODEL S (40 kWh battery)   FULL-SIZE   270
# 8  2013       TESLA         MODEL S (60 kWh battery)   FULL-SIZE   270
# 9  2013       TESLA         MODEL S (85 kWh battery)   FULL-SIZE   270
#
#   Unnamed: 5 TYPE  CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# 0         A1    B               16.9              21.4               18.7
# ...

# %%
cars.tail()
# Out:
#     YEAR   Make                   Model            Size  (kW) Unnamed: 5 TYPE  \
# 48  2016  TESLA   MODEL S 90D (Refresh)       FULL-SIZE   386         A1    B
# 49  2016  TESLA       MODEL S P85D/P90D       FULL-SIZE   568         A1    B
# 50  2016  TESLA  MODEL S P90D (Refresh)       FULL-SIZE   568         A1    B
# 51  2016  TESLA             MODEL X 90D  SUV - STANDARD   386         A1    B
# 52  2016  TESLA            MODEL X P90D  SUV - STANDARD   568         A1    B
#
#     CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 48               20.8              19.7               20.3               2.3
# 49               23.4              21.5               22.5               2.6
# 50               22.9              21.0               22.1               2.6
# 51               23.2              22.2               22.7               2.6
# 52               23.6              23.3               23.5               2.7
#
# ...

# %%
cars.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
cars[cars.isnull().any(axis=1)]
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %%
cars.columns
# Out:
# Index(['YEAR', 'Make', 'Model', 'Size', '(kW)', 'Unnamed: 5', 'TYPE',
#        'CITY (kWh/100 km)', 'HWY (kWh/100 km)', 'COMB (kWh/100 km)',
#        'CITY (Le/100 km)', 'HWY (Le/100 km)', 'COMB (Le/100 km)', '(g/km)',
#        'RATING', '(km)', 'TIME (h)'],
#       dtype='object')

# %%
cars[['(kW)','CITY (kWh/100 km)']].agg(['min','mean','max'])
# Out:
#             (kW)  CITY (kWh/100 km)
# min    35.000000           15.20000
# mean  190.622642           19.64717
# max   568.000000           23.90000

# %%
cars.dropna(axis=1, how='all',inplace = True)

# %%
cars.isnull()
# Out:
#      YEAR   Make  Model   Size   (kW)  Unnamed: 5   TYPE  CITY (kWh/100 km)  \
# 0   False  False  False  False  False       False  False              False
# 1   False  False  False  False  False       False  False              False
# 2   False  False  False  False  False       False  False              False
# 3   False  False  False  False  False       False  False              False
# 4   False  False  False  False  False       False  False              False
# 5   False  False  False  False  False       False  False              False
# 6   False  False  False  False  False       False  False              False
# 7   False  False  False  False  False       False  False              False
# 8   False  False  False  False  False       False  False              False
# 9   False  False  False  False  False       False  False              False
# 10  False  False  False  False  False       False  False              False
# ...

# %%
cars.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
animals = ['Tiger', 'Bear', 'Moose']
pd.Series(animals)
# Out:
# 0    Tiger
# 1     Bear
# 2    Moose
# dtype: object

# %%
numbers = [1, 2, 3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
numbers = [1, 2, None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
import numpy as np
np.nan == None
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
sports = {'Archery': 'Bhutan',
          'Golf': 'Scotland',
          'Sumo': 'Japan',
          'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.index[3]
# Out:
# 'Taekwondo'

# %%
type(s.index)
# Out:
# pandas.core.indexes.base.Index

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %%
s.loc['Golf']
# Out:
# 'Scotland'

# %%
s = pd.Series([104.30, 121.30, 401.50, 55.43])

# %%
total=0
for i in s:
    total+=i
print(total)
# Out:
# 682.53

# %%
import numpy as np

total = np.sum(s)
print(total)
# Out:
# 682.53

# %%
s = pd.Series(np.random.randint(0,50000,100000))
s.head()
# Out:
# 0    13302
# 1    35973
# 2    28497
# 3    18340
# 4    37175
# dtype: int32

# %%
import numpy as np
total=np.sum(s)
print(total)
# Out:
# 2495013866

# %%
len(s)
# Out:
# 100000

# %%
# %%timeit -n 100
summary = 0
for item in s:
    summary+=item
print(summary)
# Out:
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# 2495013866
# ...

# %%
# %%timeit -n 100
summary = np.sum(s)
# Out:
# 1.53 ms ± 458 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
s+=2
s.head()
# Out:
# 0    13306
# 1    35977
# 2    28501
# 3    18344
# 4    37179
# dtype: int32

# %%
s = pd.Series([1, 2, 3])
s.loc['Animal'] = 'Bears'
s
# Out:
# 0             1
# 1             2
# 2             3
# Animal    Bears
# dtype: object

# %%
original_sports = pd.Series({'Archery': 'Bhutan',
                             'Golf': 'Scotland',
                             'Sumo': 'Japan',
                             'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Australia',
                                      'Barbados',
                                      'Pakistan',
                                      'England'], 
                                   index=['Cricket',
                                          'Cricket',
                                          'Cricket',
                                          'Cricket'])
all_countries = original_sports.append(cricket_loving_countries)

# %%
original_sports
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
all_countries
# Out:
# Archery           Bhutan
# Golf            Scotland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         Barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
import pandas as pd
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])
df.head()
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df.loc['Store 2']
# Out:
# Name                  Vinod
# Item Purchased    Bird Seed
# Cost                    5.0
# Name: Store 2, dtype: object

# %%
type(df.loc['Store 2'])
# Out:
# pandas.core.series.Series

# %%
df.loc['Store 1', 'Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.T.loc['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: object

# %%
df.drop('Store 1')
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
copy_df = df.copy()
copy_df = copy_df.drop('Store 1')
copy_df
# Out:
#           Name Item Purchased  Cost
# Store 2  Vinod      Bird Seed   5.0

# %%
del copy_df['Name']
copy_df
# Out:
#         Item Purchased  Cost
# Store 2      Bird Seed   5.0

# %%
df['Location'] = None
df
# Out:
#           Name Item Purchased  Cost Location
# Store 1  Chris       Dog Food  22.5     None
# Store 1  Kevyn   Kitty Litter   2.5     None
# Store 2  Vinod      Bird Seed   5.0     None

# %%
df = pd.read_csv(r'C:\Users\KIIT\Downloads\ClassNotebooks\census.csv')
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df.fillna?

# %%
df = df.set_index('CENSUS2010POP')
df = df.sort_index()
df
# Out:
#                SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME  \
# CENSUS2010POP
# 82                 50       3         7     48     301       Texas
# 90                 50       4         9     15       5      Hawaii
# 286                50       3         7     48     269       Texas
# 416                50       3         7     48     261       Texas
# 460                50       2         4     31       5    Nebraska
# ...               ...     ...       ...    ...     ...         ...
# 12830632           40       2         3     17       0    Illinois
# 18801310           40       3         5     12       0     Florida
# 19378102           40       1         2     36       0    New York
# 25145561           40       3         7     48       0       Texas
# 37253956           40       4         9      6       0  California
#
#                       CTYNAME  ESTIMATESBASE2010  POPESTIMATE2010  \
# CENSUS2010POP
# ...

# %%
df = df.fillna(method='ffill')
df.head()
# Out:
#                SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME  \
# CENSUS2010POP
# 82                 50       3         7     48     301     Texas
# 90                 50       4         9     15       5    Hawaii
# 286                50       3         7     48     269     Texas
# 416                50       3         7     48     261     Texas
# 460                50       2         4     31       5  Nebraska
#
#                       CTYNAME  ESTIMATESBASE2010  POPESTIMATE2010  \
# CENSUS2010POP
# 82              Loving County                 82               83
# 90             Kalawao County                 90               90
# 286               King County                286              288
# 416             Kenedy County                416              418
# 460             Arthur County                460              464
#
#                POPESTIMATE2011  ...  RDOMESTICMIG2011  RDOMESTICMIG2012  \
# CENSUS2010POP                   ...
# ...
